# %%
#This Is Startup of Python Programming
#Some Basic Startups Lined below

# %%
2+3
# Out:
# 5

# %%
print (2+3)
# Out:
# 5

# %%
print('Hello World')
# Out:
# Hello World

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Section 1 - Project Complete!")
print("Looking Forward for Python Programming")
# Out:
# Section 1 - Project Complete!
# Looking Forward for Python Programming
