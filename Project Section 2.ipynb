# %%
#arithmetic operation.
#Project Section 2

# %%
400+934
# Out:
# 1334

# %%
400-934
# Out:
# -534

# %%
23*5
# Out:
# 115

# %%
15**2
# Out:
# 225

# %%
(2/5)**3
# Out:
# 0.06400000000000002

# %%
(2/5)*(2/5)
# Out:
# 0.16000000000000003

# %%
(2/5)
# Out:
# 0.4

# %%
(2/5)*(2/5)*(2/5)
# Out:
# 0.06400000000000002

# %%
2+3*5
# Out:
# 17

# %%
2-3**2
# Out:
# -7

# %%
2-3**2/9
# Out:
# 1.0

# %%
(100-90)/10
# Out:
# 1.0

# %%
from fractions import Fraction

# %%
print (Fraction(10,30))
# Out:
# 1/3

# %%
print (Fraction(100-92,-25-200))
# Out:
# -8/225

# %%
print (Fraction(100-92,-25))
# Out:
# -8/25

# %%
2+7
# Out:
# 9

# %%
19-48
# Out:
# -29

# %%
19**2
# Out:
# 361

# %%
43/5
# Out:
# 8.6

# %%
(17-8)/(18+4)
# Out:
# 0.4090909090909091
