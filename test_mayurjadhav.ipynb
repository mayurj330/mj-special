# %%
file = open("StudentsPerformance.csv","r")

# %%
import pandas
df = pandas.read_csv('StudentsPerformance.csv')
print(df)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
fun = df.groupby(["race/ethnicity","parental level of education"])["parental level of education"].count()

# %%
fun
# Out:
# race/ethnicity  parental level of education
# group A         associate's degree             14
#                 bachelor's degree              12
#                 high school                    18
#                 master's degree                 3
#                 some college                   18
#                 some high school               24
# group B         associate's degree             41
#                 bachelor's degree              20
#                 high school                    48
#                 master's degree                 6
#                 some college                   37
#                 some high school               38
# group C         associate's degree             78
#                 bachelor's degree              40
#                 high school                    64
#                 master's degree                19
#                 some college                   69
#                 some high school               49
# ...

# %%
funx =fun.T

# %%
funx = funx.reset_index(0)

# %%
funx
# Out:
#                             race/ethnicity  parental level of education
# parental level of education
# associate's degree                 group A                           14
# bachelor's degree                  group A                           12
# high school                        group A                           18
# master's degree                    group A                            3
# some college                       group A                           18
# some high school                   group A                           24
# associate's degree                 group B                           41
# bachelor's degree                  group B                           20
# high school                        group B                           48
# master's degree                    group B                            6
# some college                       group B                           37
# some high school                   group B                           38
# ...

# %%
df1=df.groupby(["gender","math score","reading score","writing score"])["parental level of education"].count()

# %%
df1["gender"]
# Out:
# gender  math score  reading score  writing score
# female  0           17             10               1
#         8           24             23               1
#         18          32             28               1
#         19          38             32               1
#         22          39             33               1
#                                                    ..
# male    99          87             81               1
#         100         96             86               1
#                     97             99               1
#                     100            93               1
#                                    100              1
# Name: parental level of education, Length: 985, dtype: int64

# %%
df["total score"] = df["math score"]+df["reading score"]+df["writing score"]
df3=df.groupby(["parental level of education","total score","lunch","test preparation course"])["parental level of education"].count()

# %%
df3
# Out:
# parental level of education  total score  lunch         test preparation course
# associate's degree           95           free/reduced  none                       1
#                              119          standard      none                       1
#                              123          free/reduced  none                       1
#                              130          free/reduced  none                       1
#                              131          standard      none                       1
#                                                                                   ..
# some high school             267          standard      completed                  2
#                              270          standard      completed                  1
#                              274          standard      none                       1
#                              289          standard      completed                  1
# ...

# %%
df4=df

# %%
df3=df.groupby(["gender","total score","test preparation course"]).median('math score')

# %%
df3
# Out:
#                                             math score  reading score  \
# gender total score test preparation course
# female 27          none                            0.0           17.0
#        55          none                            8.0           24.0
#        78          none                           18.0           32.0
#        88          none                           29.0           29.0
#        89          none                           21.5           38.0
# ...                                                ...            ...
# male   281         none                           97.0           93.0
#        282         completed                      93.5           98.0
#        293         completed                     100.0          100.0
#        296         completed                     100.0           97.0
#        300         completed                     100.0          100.0
#
#                                             writing score
# ...

# %%
df3
# Out:
# gender  total score  test preparation course
# female  27           none                        27
#         55           none                        55
#         78           none                        78
#         88           none                        88
#         89           none                        89
#                                                ...
# male    281          none                       281
#         282          completed                  282
#         293          completed                  293
#         296          completed                  296
#         300          completed                  300
# Name: total score, Length: 491, dtype: int64
