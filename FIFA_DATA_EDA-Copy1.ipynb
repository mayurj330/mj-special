# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
fifa=pd.read_csv("C:/Users/Vinayak BB/Desktop/Datasets/fifa data.csv")

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
A=fifa['club'].value_counts()[0:5].keys()
B=fifa['weight_kg'].value_counts()[0:5]
list(B),list(A)
# Out:
# ([1455, 1410, 1060, 1005, 983],
#  ['FC Barcelona',
#   'Southampton',
#   'Valencia CF',
#   'Real Valladolid CF',
#   'Paris Saint-Germain'])

# %%
for col in fifa.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
fifa.shape
# Out:
# (18278, 104)

# %%
A=fifa['nationality'].value_counts()[0:5]
B=fifa['nationality'].value_counts()[0:5].keys()

# %%
A,B
# %matplotlib inline

# %%
plt.figure(figsize=(5,5))
plt.pie(A,labels=B,autopct="%0.1f%%")
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.scatter(B,A,color="b")
plt.show()

# %%
Pl_sal=fifa[['short_name','wage_eur']]

# %%
list(Pl_sal.head())
# Out:
# ['short_name', 'wage_eur']

# %%
A=Pl_sal.sort_values(by =["wage_eur"],ascending=False).head()[0:5]
A
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000

# %%
plt.figure(figsize=(20,5))
plt.bar(A['short_name'],A['wage_eur'],color='rgby')
plt.show()
# Out:
# <ipython-input-105-b31fafdb3917>:2: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated since 3.2 and will be removed two minor releases later. Use an explicit list instead.
#   plt.bar(A['short_name'],A['wage_eur'],color='rgby')

# %%
plt.figure(figsize=(15,5))
plt.pie(A["wage_eur"],labels=A["short_name"],autopct="%0.1f%%")
plt.show()

# %%
C=(fifa["nationality"]=="Germany")
C
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18273    False
# 18274    False
# 18275    False
# 18276    False
# 18277    False
# Name: nationality, Length: 18278, dtype: bool

# %%
Germany=fifa[fifa['nationality']=='germany']

# %%
Germany.head(10)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
# 5     192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 6     192448  https://sofifa.com/player/192448/marc-andre-te...
# 7     203376  https://sofifa.com/player/203376/virgil-van-di...
# 8     177003  https://sofifa.com/player/177003/luka-modric/2...
# 9     209331  https://sofifa.com/player/209331/mohamed-salah...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# ...

# %%
Germany.sort_values(by=["height_cm"],ascending=False)[0:10]
# Out:
#        sofifa_id                                         player_url  \
# 9208      199321  https://sofifa.com/player/199321/tomas-holy/20...
# 8200      225050  https://sofifa.com/player/225050/abdoul-ba/20/...
# 12808     215408  https://sofifa.com/player/215408/aaron-chapman...
# 3121      192613  https://sofifa.com/player/192613/costel-pantil...
# 12864     237015  https://sofifa.com/player/237015/mikkel-mena-q...
# 17365     241870  https://sofifa.com/player/241870/matt-casey/20...
# 5451      199074  https://sofifa.com/player/199074/lacina-traore...
# 17149     243387  https://sofifa.com/player/243387/samuel-brolin...
# 4868      224836  https://sofifa.com/player/224836/vanja-milinko...
# 7725      243675  https://sofifa.com/player/243675/kjell-scherpe...
#
#                 short_name               long_name  age         dob  \
# 9208               T. Holý              Tomáš Holý   27  1991-12-10
# 8200                 A. Ba               Abdoul Ba   25  1994-02-08
# ...

# %%
Germany.sort_values(by=["weight_kg"],ascending=False)[0:10]
# Out:
#        sofifa_id                                         player_url  \
# 10693     156321  https://sofifa.com/player/156321/adebayo-akinf...
# 9572      179685  https://sofifa.com/player/179685/chris-seitz/2...
# 15064     237399  https://sofifa.com/player/237399/evan-louro/20...
# 7439      195357  https://sofifa.com/player/195357/fabien-farnol...
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
# 11945     190169  https://sofifa.com/player/190169/dennis-telgen...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 11561     190822  https://sofifa.com/player/190822/eirik-holmen-...
# 9208      199321  https://sofifa.com/player/199321/tomas-holy/20...
# 2278      194904  https://sofifa.com/player/194904/bill-hamid/20...
#
#           short_name              long_name  age         dob  height_cm  \
# 10693   A. Akinfenwa      Adebayo Akinfenwa   37  1982-05-10        178
# 9572        C. Seitz            Chris Seitz   32  1987-03-12        191
# ...

# %%
Germany.sort_values(by=["wage_eur"],ascending=False)
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 5         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 22        194765  https://sofifa.com/player/194765/antoine-griez...
# ...          ...                                                ...
# 565       245294  https://sofifa.com/player/245294/jorge-ezequie...
# 1868      216742  https://sofifa.com/player/216742/miha-mevlja/2...
# 14723     248052  https://sofifa.com/player/248052/roberto-ferna...
# 16356     252735  https://sofifa.com/player/252735/hristo-ivanov...
# 3053      181795  https://sofifa.com/player/181795/fedor-kudryas...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
Germany=fifa[fifa['nationality']=='Germany']

# %%
Germany.head()
# Out:
#     sofifa_id                                         player_url  \
# 6      192448  https://sofifa.com/player/192448/marc-andre-te...
# 31     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37     188350  https://sofifa.com/player/188350/marco-reus/20...
# 49     178603  https://sofifa.com/player/178603/mats-hummels/...
#
#        short_name              long_name  age         dob  height_cm  \
# 6   M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# 31       M. Neuer           Manuel Neuer   33  1986-03-27        193
# 36       T. Kroos             Toni Kroos   29  1990-01-04        183
# 37        M. Reus             Marco Reus   30  1989-05-31        180
# 49     M. Hummels          Mats  Hummels   30  1988-12-16        191
#
#     weight_kg nationality               club  ...   lwb   ldm   cdm   rdm  \
# 6          85     Germany       FC Barcelona  ...   NaN   NaN   NaN   NaN
# ...
