# %%
list1 = [0,1,2,3,4]

# %%
list1
# Out:
# [0, 1, 2, 3, 4]

# %%
print (list1)
# Out:
# [0, 1, 2, 3, 4]

# %%
list2=[5,8,6,9]

# %%
list1+list2
# Out:
# [0, 1, 2, 3, 4, 5, 6, 8, 9]

# %%
list3 =["cat","nat"]

# %%
list4=list1+list2+list3

# %%
list4
# Out:
# [0, 1, 2, 3, 4, 5, 6, 8, 9, 'cat', 'nat']

# %%
list4[9]
# Out:
# 'cat'

# %%
list4[0]  = "mat"

# %%
list4
# Out:
# ['mat', 1, 2, 3, 4, 5, 6, 8, 9, 'cat', 'nat']

# %%
list4.append("mayur")

# %%
list4
# Out:
# ['mat', 1, 2, 3, 4, 5, 6, 8, 9, 'cat', 'nat']

# %%
list4.pop(0)
# Out:
# 'mat'

# %%
list4
# Out:
# [1, 2, 3, 4, 5, 6, 8, 9, 'cat', 'nat']

# %%
list2.sort(reverse = False)

# %%
list2
# Out:
# [5, 6, 8, 9]

# %%
list6 = list2

# %%
list6
# Out:
# [5, 6, 8, 9]

# %%
list6.sort(reverse = True)

# %%
list6
# Out:
# [9, 8, 6, 5]

# %%
list2
# Out:
# [9, 8, 6, 5]

# %%
list6 = list2.copy()

# %%
list6+list2
# Out:
# [9, 8, 6, 5, 9, 8, 6, 5]

# %%
list6.sort(reverse = False)

# %%
list2
# Out:
# [9, 8, 6, 5]

# %%
list6
# Out:
# [5, 6, 8, 9]

# %%
list2
# Out:
# [9, 8, 6, 5]
